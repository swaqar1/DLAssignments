# %% [markdown]
# ## **CAR PRICE PREDICTION MODEL**

# %% [markdown]
# A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts.
#
# They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#
# Which variables are significant in predicting the price of a car How well those variables describe the price of a car Based on various market surveys, the consulting firm has gathered a large data set of different types of cars across the America market.
#
# task::
# We are required to model the price of cars with the available independent variables. It will be used by the management to understand how exactly the prices vary with the independent variables. They can accordingly manipulate the design of the cars, the business strategy etc. to meet certain price levels. Further, the model will be a good way for management to understand the pricing dynamics of a new market.
#
# WORKFLOW ::
#
# 1.Load Data
#
# 2.Check Missing Values ( If Exist ; Fill each record with mean of its feature )
#
# 3.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
#
# 4.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
#
# 5.Compilation Step (Note : Its a Regression problem , select loss , metrics according to it) 6.Train the Model with Epochs (100) and validate it
#
# 7.If the model gets overfit tune your model by changing the units , No. of layers , activation function , epochs , add dropout layer or add Regularizer according to the need .
#
# 8.Evaluation Step
#
# 9.Prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow.keras as tf
from tensorflow.keras import models, layers, optimizers

# %%
import io
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-09664da7-6d37-4914-a578-110d0b657d3f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-09664da7-6d37-4914-a578-110d0b657d3f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CarPrice_Assignment.csv to CarPrice_Assignment.csv

# %% [markdown]
# CSV Loading

# %%
car_data = pd.read_csv("CarPrice_Assignment.csv")
car_data.head(10)
# Out:
#    car_ID  symboling                   CarName  ... citympg highwaympg      price
# 0       1          3        alfa-romero giulia  ...      21         27  13495.000
# 1       2          3       alfa-romero stelvio  ...      21         27  16500.000
# 2       3          1  alfa-romero Quadrifoglio  ...      19         26  16500.000
# 3       4          2               audi 100 ls  ...      24         30  13950.000
# 4       5          2                audi 100ls  ...      18         22  17450.000
# 5       6          2                  audi fox  ...      19         25  15250.000
# 6       7          1                audi 100ls  ...      19         25  17710.000
# 7       8          1                 audi 5000  ...      19         25  18920.000
# 8       9          1                 audi 4000  ...      17         20  23875.000
# 9      10          0       audi 5000s (diesel)  ...      16         22  17859.167
#
# [10 rows x 26 columns]

# %%
car_data['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
#        'mazda glc deluxe', 'mazda 626', 'mazda glc', 'mazda rx-7 gs',
#        'mazda glc 4', 'mazda glc custom l', 'mazda glc custom',
#        'buick electra 225 custom', 'buick century luxus (sw)',
#        'buick century', 'buick skyhawk', 'buick opel isuzu deluxe',
#        'buick skylark', 'buick century special',
#        'buick regal sport coupe (turbo)', 'mercury cougar',
#        'mitsubishi mirage', 'mitsubishi lancer', 'mitsubishi outlander',
#        'mitsubishi g4', 'mitsubishi mirage g4', 'mitsubishi montero',
#        'mitsubishi pajero', 'Nissan versa', 'nissan gt-r', 'nissan rogue',
#        'nissan latio', 'nissan titan', 'nissan leaf', 'nissan juke',
#        'nissan note', 'nissan clipper', 'nissan nv200', 'nissan dayz',
#        'nissan fuga', 'nissan otti', 'nissan teana', 'nissan kicks',
#        'peugeot 504', 'peugeot 304', 'peugeot 504 (sw)', 'peugeot 604sl',
#        'peugeot 505s turbo diesel', 'plymouth fury iii',
#        'plymouth cricket', 'plymouth satellite custom (sw)',
#        'plymouth fury gran sedan', 'plymouth valiant', 'plymouth duster',
#        'porsche macan', 'porcshce panamera', 'porsche cayenne',
#        'porsche boxter', 'renault 12tl', 'renault 5 gtl', 'saab 99e',
#        'saab 99le', 'saab 99gle', 'subaru', 'subaru dl', 'subaru brz',
#        'subaru baja', 'subaru r1', 'subaru r2', 'subaru trezia',
#        'subaru tribeca', 'toyota corona mark ii', 'toyota corona',
#        'toyota corolla 1200', 'toyota corona hardtop',
#        'toyota corolla 1600 (sw)', 'toyota carina', 'toyota mark ii',
#        'toyota corolla', 'toyota corolla liftback',
#        'toyota celica gt liftback', 'toyota corolla tercel',
#        'toyota corona liftback', 'toyota starlet', 'toyota tercel',
#        'toyota cressida', 'toyota celica gt', 'toyouta tercel',
#        'vokswagen rabbit', 'volkswagen 1131 deluxe sedan',
#        'volkswagen model 111', 'volkswagen type 3', 'volkswagen 411 (sw)',
#        'volkswagen super beetle', 'volkswagen dasher', 'vw dasher',
#        'vw rabbit', 'volkswagen rabbit', 'volkswagen rabbit custom',
#        'volvo 145e (sw)', 'volvo 144ea', 'volvo 244dl', 'volvo 245',
#        'volvo 264gl', 'volvo diesel', 'volvo 246'], dtype=object)

# %%
np.where(car_data.applymap(lambda x: x ==''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
car_data.isnull().any()
# Out:
# car_ID              False
# symboling           False
# CarName             False
# fueltype            False
# aspiration          False
# doornumber          False
# carbody             False
# drivewheel          False
# enginelocation      False
# wheelbase           False
# carlength           False
# carwidth            False
# carheight           False
# curbweight          False
# enginetype          False
# cylindernumber      False
# enginesize          False
# fuelsystem          False
# boreratio           False
# stroke              False
# compressionratio    False
# horsepower          False
# peakrpm             False
# citympg             False
# highwaympg          False
# price               False
# dtype: bool

# %%
# correct the name error in audi 100 ls
car_data.iloc[3,2] = 'audi 100ls'

# %%
car_data.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
car_data.drop(columns=['car_ID'], inplace = True)

# %%
# get columns so that we can use the column names for onehot encoding of catagorical featrues in next cell
car_data.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
# onehot encode all catagorical columns
final_car = pd.get_dummies(car_data, columns=['CarName','symboling','fueltype',	'aspiration',	'doornumber',	'carbody',	'drivewheel',	'enginelocation',	'enginetype',	'cylindernumber',	'fuelsystem'], drop_first = True)

# %%
final_car.head()
# Out:
#    wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 0       88.6      168.8  ...                0                0
# 1       88.6      168.8  ...                0                0
# 2       94.5      171.2  ...                0                0
# 3       99.8      176.6  ...                0                0
# 4       99.4      176.6  ...                0                0
#
# [5 rows x 193 columns]

# %%
#check statistical data to see abnormal values and outliers
final_car.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  205.000000  205.000000  ...       205.000000       205.000000
# mean    98.756585  174.049268  ...         0.043902         0.004878
# std      6.021776   12.337289  ...         0.205380         0.069843
# min     86.600000  141.100000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     97.000000  173.200000  ...         0.000000         0.000000
# 75%    102.400000  183.100000  ...         0.000000         0.000000
# max    120.900000  208.100000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
#initialize a seed value so that each time we can get the same random number sequence, it will help us  as a team
# working on a common project to work on the same random data. Each new seed will generate a particular sequnce
#of random number. You can choose any seed value here of your choice
# 0.72 means we have taken 72% values for training set as we will make 72/4 = 18 rows of k fold validation data, where
# value of k will be 4 when we compile and fit our model for validation
np.random.seed(11111)
msk = np.random.rand(len(final_car)) < 0.72
train_total = final_car[msk]
test_total = final_car[~msk]

# %%
#check the length of our test and train datasets
print(len(train_total))
print(len(test_total))
# Out:
# 141
# 64

# %%
train_total.head(10)
# Out:
#     wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1        88.6      168.8  ...                0                0
# 2        94.5      171.2  ...                0                0
# 3        99.8      176.6  ...                0                0
# 4        99.4      176.6  ...                0                0
# 5        99.8      177.3  ...                0                0
# 6       105.8      192.7  ...                0                0
# 7       105.8      192.7  ...                0                0
# 8       105.8      192.7  ...                0                0
# 9        99.5      178.2  ...                0                0
# 11      101.2      176.8  ...                0                0
#
# [10 rows x 193 columns]

# %%
# check statistical overview if there are some outliers and abnormal values
train_total.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  141.000000  141.000000  ...       141.000000       141.000000
# mean    98.692199  173.658156  ...         0.035461         0.007092
# std      6.005665   12.320089  ...         0.185601         0.084215
# min     86.600000  144.600000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     96.500000  172.400000  ...         0.000000         0.000000
# 75%    102.400000  180.300000  ...         0.000000         0.000000
# max    115.600000  202.600000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
print(train_total.dtypes)
# Out:
# wheelbase          float64
# carlength          float64
# carwidth           float64
# carheight          float64
# curbweight           int64
#                     ...
# fuelsystem_idi       uint8
# fuelsystem_mfi       uint8
# fuelsystem_mpfi      uint8
# fuelsystem_spdi      uint8
# fuelsystem_spfi      uint8
# Length: 193, dtype: object

# %%
# get our price labels and store in another dataframe
train_label = train_total.loc[:,'price']
test_label = test_total.loc[:,'price']

# %%
# drop price from oroginal training and test dataset , as price is not needed there
test_data= test_total.drop(columns = ['price'])
train_data= train_total.drop(columns = ['price'])

# %%
train_data.shape
# Out:
# (141, 192)

# %%
train_data
# Out:
#      wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1         88.6      168.8  ...                0                0
# 2         94.5      171.2  ...                0                0
# 3         99.8      176.6  ...                0                0
# 4         99.4      176.6  ...                0                0
# 5         99.8      177.3  ...                0                0
# ..         ...        ...  ...              ...              ...
# 200      109.1      188.8  ...                0                0
# 201      109.1      188.8  ...                0                0
# 202      109.1      188.8  ...                0                0
# 203      109.1      188.8  ...                0                0
# 204      109.1      188.8  ...                0                0
#
# [141 rows x 192 columns]

# %%
#get indices of the columns so that we can know how many columns we have to normalize, as catagorical columns which we
# have added with onehot encoding, do not need to be normalized.. normalizing will be done in next cell
{train_data.columns.get_loc(c): c for idx, c in enumerate(train_data.columns)}
# Out:
# {0: 'wheelbase',
#  1: 'carlength',
#  2: 'carwidth',
#  3: 'carheight',
#  4: 'curbweight',
#  5: 'enginesize',
#  6: 'boreratio',
#  7: 'stroke',
#  8: 'compressionratio',
#  9: 'horsepower',
#  10: 'peakrpm',
#  11: 'citympg',
#  12: 'highwaympg',
#  13: 'CarName_alfa-romero Quadrifoglio',
#  14: 'CarName_alfa-romero giulia',
#  15: 'CarName_alfa-romero stelvio',
#  16: 'CarName_audi 100ls',
#  17: 'CarName_audi 4000',
#  18: 'CarName_audi 5000',
#  19: 'CarName_audi 5000s (diesel)',
#  20: 'CarName_audi fox',
#  21: 'CarName_bmw 320i',
#  22: 'CarName_bmw x1',
#  23: 'CarName_bmw x3',
#  24: 'CarName_bmw x4',
#  25: 'CarName_bmw x5',
#  26: 'CarName_bmw z4',
#  27: 'CarName_buick century',
#  28: 'CarName_buick century luxus (sw)',
#  29: 'CarName_buick century special',
#  30: 'CarName_buick electra 225 custom',
#  31: 'CarName_buick opel isuzu deluxe',
#  32: 'CarName_buick regal sport coupe (turbo)',
#  33: 'CarName_buick skyhawk',
#  34: 'CarName_buick skylark',
#  35: 'CarName_chevrolet impala',
#  36: 'CarName_chevrolet monte carlo',
#  37: 'CarName_chevrolet vega 2300',
#  38: 'CarName_dodge challenger se',
#  39: 'CarName_dodge colt (sw)',
#  40: 'CarName_dodge colt hardtop',
#  41: 'CarName_dodge coronet custom',
#  42: 'CarName_dodge coronet custom (sw)',
#  43: 'CarName_dodge d200',
#  44: 'CarName_dodge dart custom',
#  45: 'CarName_dodge monaco (sw)',
#  46: 'CarName_dodge rampage',
#  47: 'CarName_honda accord',
#  48: 'CarName_honda accord cvcc',
#  49: 'CarName_honda accord lx',
#  50: 'CarName_honda civic',
#  51: 'CarName_honda civic (auto)',
#  52: 'CarName_honda civic 1300',
#  53: 'CarName_honda civic 1500 gl',
#  54: 'CarName_honda civic cvcc',
#  55: 'CarName_honda prelude',
#  56: 'CarName_isuzu D-Max ',
#  57: 'CarName_isuzu D-Max V-Cross',
#  58: 'CarName_isuzu MU-X',
#  59: 'CarName_jaguar xf',
#  60: 'CarName_jaguar xj',
#  61: 'CarName_jaguar xk',
#  62: 'CarName_maxda glc deluxe',
#  63: 'CarName_maxda rx3',
#  64: 'CarName_mazda 626',
#  65: 'CarName_mazda glc',
#  66: 'CarName_mazda glc 4',
#  67: 'CarName_mazda glc custom',
#  68: 'CarName_mazda glc custom l',
#  69: 'CarName_mazda glc deluxe',
#  70: 'CarName_mazda rx-4',
#  71: 'CarName_mazda rx-7 gs',
#  72: 'CarName_mazda rx2 coupe',
#  73: 'CarName_mercury cougar',
#  74: 'CarName_mitsubishi g4',
#  75: 'CarName_mitsubishi lancer',
#  76: 'CarName_mitsubishi mirage',
#  77: 'CarName_mitsubishi mirage g4',
#  78: 'CarName_mitsubishi montero',
#  79: 'CarName_mitsubishi outlander',
#  80: 'CarName_mitsubishi pajero',
#  81: 'CarName_nissan clipper',
#  82: 'CarName_nissan dayz',
#  83: 'CarName_nissan fuga',
#  84: 'CarName_nissan gt-r',
#  85: 'CarName_nissan juke',
#  86: 'CarName_nissan kicks',
#  87: 'CarName_nissan latio',
#  88: 'CarName_nissan leaf',
#  89: 'CarName_nissan note',
#  90: 'CarName_nissan nv200',
#  91: 'CarName_nissan otti',
#  92: 'CarName_nissan rogue',
#  93: 'CarName_nissan teana',
#  94: 'CarName_nissan titan',
#  95: 'CarName_peugeot 304',
#  96: 'CarName_peugeot 504',
#  97: 'CarName_peugeot 504 (sw)',
#  98: 'CarName_peugeot 505s turbo diesel',
#  99: 'CarName_peugeot 604sl',
#  100: 'CarName_plymouth cricket',
#  101: 'CarName_plymouth duster',
#  102: 'CarName_plymouth fury gran sedan',
#  103: 'CarName_plymouth fury iii',
#  104: 'CarName_plymouth satellite custom (sw)',
#  105: 'CarName_plymouth valiant',
#  106: 'CarName_porcshce panamera',
#  107: 'CarName_porsche boxter',
#  108: 'CarName_porsche cayenne',
#  109: 'CarName_porsche macan',
#  110: 'CarName_renault 12tl',
#  111: 'CarName_renault 5 gtl',
#  112: 'CarName_saab 99e',
#  113: 'CarName_saab 99gle',
#  114: 'CarName_saab 99le',
#  115: 'CarName_subaru',
#  116: 'CarName_subaru baja',
#  117: 'CarName_subaru brz',
#  118: 'CarName_subaru dl',
#  119: 'CarName_subaru r1',
#  120: 'CarName_subaru r2',
#  121: 'CarName_subaru trezia',
#  122: 'CarName_subaru tribeca',
#  123: 'CarName_toyota carina',
#  124: 'CarName_toyota celica gt',
#  125: 'CarName_toyota celica gt liftback',
#  126: 'CarName_toyota corolla',
#  127: 'CarName_toyota corolla 1200',
#  128: 'CarName_toyota corolla 1600 (sw)',
#  129: 'CarName_toyota corolla liftback',
#  130: 'CarName_toyota corolla tercel',
#  131: 'CarName_toyota corona',
#  132: 'CarName_toyota corona hardtop',
#  133: 'CarName_toyota corona liftback',
#  134: 'CarName_toyota corona mark ii',
#  135: 'CarName_toyota cressida',
#  136: 'CarName_toyota mark ii',
#  137: 'CarName_toyota starlet',
#  138: 'CarName_toyota tercel',
#  139: 'CarName_toyouta tercel',
#  140: 'CarName_vokswagen rabbit',
#  141: 'CarName_volkswagen 1131 deluxe sedan',
#  142: 'CarName_volkswagen 411 (sw)',
#  143: 'CarName_volkswagen dasher',
#  144: 'CarName_volkswagen model 111',
#  145: 'CarName_volkswagen rabbit',
#  146: 'CarName_volkswagen rabbit custom',
#  147: 'CarName_volkswagen super beetle',
#  148: 'CarName_volkswagen type 3',
#  149: 'CarName_volvo 144ea',
#  150: 'CarName_volvo 145e (sw)',
#  151: 'CarName_volvo 244dl',
#  152: 'CarName_volvo 245',
#  153: 'CarName_volvo 246',
#  154: 'CarName_volvo 264gl',
#  155: 'CarName_volvo diesel',
#  156: 'CarName_vw dasher',
#  157: 'CarName_vw rabbit',
#  158: 'symboling_-1',
#  159: 'symboling_0',
#  160: 'symboling_1',
#  161: 'symboling_2',
#  162: 'symboling_3',
#  163: 'fueltype_gas',
#  164: 'aspiration_turbo',
#  165: 'doornumber_two',
#  166: 'carbody_hardtop',
#  167: 'carbody_hatchback',
#  168: 'carbody_sedan',
#  169: 'carbody_wagon',
#  170: 'drivewheel_fwd',
#  171: 'drivewheel_rwd',
#  172: 'enginelocation_rear',
#  173: 'enginetype_dohcv',
#  174: 'enginetype_l',
#  175: 'enginetype_ohc',
#  176: 'enginetype_ohcf',
#  177: 'enginetype_ohcv',
#  178: 'enginetype_rotor',
#  179: 'cylindernumber_five',
#  180: 'cylindernumber_four',
#  181: 'cylindernumber_six',
#  182: 'cylindernumber_three',
#  183: 'cylindernumber_twelve',
#  184: 'cylindernumber_two',
#  185: 'fuelsystem_2bbl',
#  186: 'fuelsystem_4bbl',
#  187: 'fuelsystem_idi',
#  188: 'fuelsystem_mfi',
#  189: 'fuelsystem_mpfi',
#  190: 'fuelsystem_spdi',
#  191: 'fuelsystem_spfi'}

# %%
## we normalize data because data has big vlaues in decimal and it will worsen performance of our model, may overfit 
## or  we may face hardware resource high usage
# we will apply the formula normalized_train_data = (train_data - mean)/ stadrad_deviation
## firt take mean of training, then subtract mean from each value of the array slice train_data.iloc[:,0:13]
mean = train_data.iloc[:,0:13].mean(axis=0) # taking the mean of 
train_data.iloc[:,0:13] -= mean
std = train_data.iloc[:,0:13].std(axis=0)
train_data.iloc[:,0:13] /= std
test_data.iloc[:,0:13] -= mean
test_data.iloc[:,0:13] /= std

# %%
mean
# Out:
# wheelbase             98.692199
# carlength            173.658156
# carwidth              65.875887
# carheight             53.648227
# curbweight          2546.787234
# enginesize           125.666667
# boreratio              3.324184
# stroke                 3.256809
# compressionratio      10.070355
# horsepower           103.702128
# peakrpm             5143.971631
# citympg               25.113475
# highwaympg            30.581560
# dtype: float64

# %%
std
# Out:
# wheelbase             6.005665
# carlength            12.320089
# carwidth              2.188604
# carheight             2.508204
# curbweight          529.769152
# enginesize           41.733451
# boreratio             0.266123
# stroke                0.296387
# compressionratio      3.868579
# horsepower           38.424275
# peakrpm             474.472458
# citympg               6.509435
# highwaympg            6.734937
# dtype: float64

# %%
mean_label = train_label.mean()
train_label -= mean_label
std_label = train_label.std()
train_label /= std_label
test_label -= mean_label
test_label /= std_label

# %%
mean_label
# Out:
# 13379.132390070921

# %%
std_label
# Out:
# 8189.4945680106175

# %%
test_label
# Out:
# 0      0.014148
# 10     0.372534
# 14     1.365880
# 15     2.122337
# 18    -1.004718
#          ...
# 192    0.056886
# 193   -0.132991
# 194   -0.053621
# 196    0.318196
# 198    0.615529
# Name: price, Length: 64, dtype: float64

# %%
train_data.shape
# Out:
# (141, 192)

# %%
#store in numpy array

# %%
test = np.array(test_data.iloc[:]).astype('float32')

# %%
train = np.array(train_data.iloc[:]).astype('float32')

# %%
test_l= np.array(test_label.astype('float32'))

# %%
train_l= np.array(train_label.astype('float32'))

# %%
train.shape[1]
# Out:
# 192

# %%
(141,192)[1]
# Out:
# 192

# %%
train.dtype
# Out:
# dtype('float32')

# %% [markdown]
# ## **Models Building**

# %% [markdown]
# We will configure different models here according to relu, tanh , regularization, dropout etc..

# %%
# we are passing activation function as a parameter here so that we can call this function with tanh or relu while
# fitting and training the model
from keras import models
from keras import layers
def build_model(act):
  model = models.Sequential()
  model.add(layers.Dense(128, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dense(64, activation= act))
  model.add(layers.Dense(32, activation= act))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model('relu').summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               24704
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
build_model('tanh').summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 128)               24704
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Regularized model
from keras import regularizers
def build_model_regular(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001),input_shape=(train.shape[1],)))
  model.add(layers.Dense(8, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(6, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_regular('tanh').summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 10)                1930
# _________________________________________________________________
# dense_9 (Dense)              (None, 8)                 88
# _________________________________________________________________
# dense_10 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 2,079
# Trainable params: 2,079
# Non-trainable params: 0
# _________________________________________________________________

# %%
# dropout model
from keras import regularizers
def build_model_drop(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(8, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(6, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_drop('relu').summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 10)                1930
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 8)                 88
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_14 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 2,079
# Trainable params: 2,079
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## **K Fold validation section**
#
# Here we will use len(train)//k to make 141//4 = 36 rows for validation in each validation test and collect the validation scores for relu , tanh , regularization , and dropout

# %%
#K-fold validation with relu
# 141/4
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_relu = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_relu.append(val_mae)
# Out:
# processing fold # 0
# processing fold # 1
# processing fold # 2
# processing fold # 3

# %%
# 141/4
#K-fold validation with tanh
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_tanh = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('tanh')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_tanh.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4fc94668c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4fc9d6d440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4fcb8648c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4fcdea49e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#K-fold validtion with regularization
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_regular = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_regular('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_regular.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4fc829ed40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4fc829ea70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4fca4b5200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4fca249830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#K-fold validtion with dropout
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_drop = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_drop('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=1)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=1)
  all_scores_drop.append(val_mae)
# Out:
# processing fold # 0
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 1.0630 - mae: 0.7423
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9523 - mae: 0.6474
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8994 - mae: 0.6126
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4415 - mae: 0.4799
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5232 - mae: 0.5191
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4200 - mae: 0.4478
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5325 - mae: 0.4866
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4130 - mae: 0.4464
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6898 - mae: 0.5106
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8762 - mae: 0.5742
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5275 - mae: 0.4621
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2450 - mae: 0.3387
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5260 - mae: 0.5006
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3104 - mae: 0.3783
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1967 - mae: 0.3233
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.1811 - mae: 0.5750
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3164 - mae: 0.3858
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2785 - mae: 0.3505
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2899 - mae: 0.3777
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3174 - mae: 0.3604
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2707 - mae: 0.3373
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4009 - mae: 0.3863
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6444 - mae: 0.4222
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2578 - mae: 0.3866
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2095 - mae: 0.3084
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3024 - mae: 0.3855
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2425 - mae: 0.3133
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2714 - mae: 0.3515
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1957 - mae: 0.3156
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1953 - mae: 0.3211
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3908 - mae: 0.3532
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1896 - mae: 0.2719
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3489 - mae: 0.3924
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0913 - mae: 0.2311
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1636 - mae: 0.2734
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3412 - mae: 0.3402
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4450 - mae: 0.3828
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5706 - mae: 0.4369
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4479 - mae: 0.3927
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2888 - mae: 0.3393
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2427 - mae: 0.3028
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2923 - mae: 0.3709
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2146 - mae: 0.2742
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2857 - mae: 0.3058
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2158 - mae: 0.3255
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1991 - mae: 0.3283
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2400 - mae: 0.3166
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1601 - mae: 0.3070
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2449 - mae: 0.3132
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3136 - mae: 0.3109
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1913 - mae: 0.2987
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2633 - mae: 0.3231
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2121 - mae: 0.2701
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3444 - mae: 0.3424
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1431 - mae: 0.2579
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2731 - mae: 0.2884
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6914 - mae: 0.4611
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1124 - mae: 0.2452
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2884 - mae: 0.3178
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3512 - mae: 0.3731
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2705 - mae: 0.3226
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1497 - mae: 0.2540
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1969 - mae: 0.2974
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1871 - mae: 0.3033
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3214 - mae: 0.3257
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4934 - mae: 0.3799
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2960 - mae: 0.3300
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3502 - mae: 0.3604
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1203 - mae: 0.2527
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2354 - mae: 0.3129
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2744 - mae: 0.2783
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1691 - mae: 0.2806
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4767 - mae: 0.4272
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1850 - mae: 0.2821
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2647 - mae: 0.3167
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1847 - mae: 0.2953
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4183 - mae: 0.3910
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2325 - mae: 0.2859
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1764 - mae: 0.2666
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2693 - mae: 0.3205
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2018 - mae: 0.2862
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3043 - mae: 0.3207
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3085 - mae: 0.3227
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1221 - mae: 0.2273
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1703 - mae: 0.2596
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2481 - mae: 0.2905
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1310 - mae: 0.2754
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2285 - mae: 0.2909
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3907 - mae: 0.3390
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2150 - mae: 0.3051
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1990 - mae: 0.2927
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5178 - mae: 0.3965
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2618 - mae: 0.3241
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3929 - mae: 0.3762
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1582 - mae: 0.2958
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1844 - mae: 0.2727
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1611 - mae: 0.2663
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1388 - mae: 0.2699
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2087 - mae: 0.3244
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1157 - mae: 0.2343
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4fcaf03440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3774 - mae: 0.4010
# processing fold # 1
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.5890 - mae: 0.6161
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4738 - mae: 0.5428
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6267 - mae: 0.5569
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4149 - mae: 0.4567
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4059 - mae: 0.4199
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3023 - mae: 0.4183
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2423 - mae: 0.3752
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3184 - mae: 0.3779
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3254 - mae: 0.4397
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4125 - mae: 0.4607
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6487 - mae: 0.4770
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2853 - mae: 0.3653
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2021 - mae: 0.2899
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2026 - mae: 0.3329
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4299 - mae: 0.3712
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3588 - mae: 0.3772
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3959 - mae: 0.3914
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6142 - mae: 0.4656
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3623 - mae: 0.4072
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4454 - mae: 0.4648
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3304 - mae: 0.3996
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4009 - mae: 0.4090
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2729 - mae: 0.3587
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2062 - mae: 0.3335
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1833 - mae: 0.3204
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2214 - mae: 0.3677
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6948 - mae: 0.4940
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2291 - mae: 0.3281
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3629 - mae: 0.3693
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1775 - mae: 0.2890
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2890 - mae: 0.3575
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2002 - mae: 0.3168
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3221 - mae: 0.3624
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2786 - mae: 0.3024
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1391 - mae: 0.2679
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2897 - mae: 0.3805
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4554 - mae: 0.4076
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1455 - mae: 0.2848
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1046 - mae: 0.2472
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2612 - mae: 0.3442
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2000 - mae: 0.2853
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1605 - mae: 0.2644
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2370 - mae: 0.3017
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1794 - mae: 0.2774
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2282 - mae: 0.3149
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1281 - mae: 0.2817
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3900 - mae: 0.3829
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2727 - mae: 0.3064
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2931 - mae: 0.3499
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1288 - mae: 0.2655
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1214 - mae: 0.2507
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1731 - mae: 0.3060
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4581 - mae: 0.3673
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2761 - mae: 0.3407
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2853 - mae: 0.3080
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1642 - mae: 0.2846
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1669 - mae: 0.3013
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1814 - mae: 0.3061
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2166 - mae: 0.3163
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2166 - mae: 0.2896
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2854 - mae: 0.3475
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1346 - mae: 0.2582
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1787 - mae: 0.2697
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1623 - mae: 0.2777
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4152 - mae: 0.3303
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1547 - mae: 0.2825
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5512 - mae: 0.4114
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2050 - mae: 0.3115
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2078 - mae: 0.2520
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3103 - mae: 0.2854
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2205 - mae: 0.2897
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1046 - mae: 0.2349
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1810 - mae: 0.3064
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1262 - mae: 0.2378
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0922 - mae: 0.2359
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2230 - mae: 0.2719
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1620 - mae: 0.2498
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2207 - mae: 0.2886
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5219 - mae: 0.3703
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1261 - mae: 0.2540
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2849 - mae: 0.3078
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2075 - mae: 0.2752
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1126 - mae: 0.2135
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0958 - mae: 0.2172
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0939 - mae: 0.2131
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1921 - mae: 0.2545
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0870 - mae: 0.2145
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6284 - mae: 0.4428
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1563 - mae: 0.2299
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1490 - mae: 0.2456
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1151 - mae: 0.2523
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1825 - mae: 0.2760
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1492 - mae: 0.2473
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1670 - mae: 0.2706
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1052 - mae: 0.2180
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3140 - mae: 0.2578
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1112 - mae: 0.2576
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1869 - mae: 0.2586
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1314 - mae: 0.2592
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1186 - mae: 0.2150
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4fca453050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5731 - mae: 0.4334
# processing fold # 2
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 1.2514 - mae: 0.8667
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.2701 - mae: 0.8052
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5773 - mae: 0.5493
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6911 - mae: 0.5963
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4722 - mae: 0.4643
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6193 - mae: 0.5314
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7026 - mae: 0.5504
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5695 - mae: 0.4684
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2672 - mae: 0.3661
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3523 - mae: 0.3672
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5242 - mae: 0.3985
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3160 - mae: 0.4213
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5695 - mae: 0.5204
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3008 - mae: 0.4005
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5987 - mae: 0.4292
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2505 - mae: 0.3468
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4085 - mae: 0.3858
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6236 - mae: 0.4556
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2784 - mae: 0.3669
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3087 - mae: 0.3606
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1965 - mae: 0.3197
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1841 - mae: 0.2978
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6603 - mae: 0.4461
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3364 - mae: 0.3771
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4256 - mae: 0.4319
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4608 - mae: 0.3907
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2988 - mae: 0.3416
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3955 - mae: 0.4259
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2215 - mae: 0.3208
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3379 - mae: 0.3575
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2747 - mae: 0.3414
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3149 - mae: 0.3745
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2632 - mae: 0.3330
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4287 - mae: 0.4073
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8581 - mae: 0.4873
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4363 - mae: 0.4217
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3174 - mae: 0.3267
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3168 - mae: 0.3902
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1443 - mae: 0.2809
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6551 - mae: 0.5184
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2315 - mae: 0.3122
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5219 - mae: 0.4076
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4082 - mae: 0.3618
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1588 - mae: 0.2642
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2868 - mae: 0.3364
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3080 - mae: 0.3486
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2778 - mae: 0.3337
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3967 - mae: 0.3404
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3584 - mae: 0.3846
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2618 - mae: 0.3240
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2709 - mae: 0.3397
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1813 - mae: 0.2820
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3667 - mae: 0.3839
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3280 - mae: 0.3369
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2777 - mae: 0.3314
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3491 - mae: 0.3167
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2448 - mae: 0.3236
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1886 - mae: 0.2918
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1840 - mae: 0.2683
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2620 - mae: 0.3148
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2048 - mae: 0.3348
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1279 - mae: 0.2521
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1143 - mae: 0.2327
# Epoch 64/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3915 - mae: 0.4120
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1048 - mae: 0.2489
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1495 - mae: 0.2865
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2004 - mae: 0.3212
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1948 - mae: 0.2998
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0890 - mae: 0.2246
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2151 - mae: 0.3101
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4426 - mae: 0.3993
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1968 - mae: 0.2904
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4647 - mae: 0.4282
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1869 - mae: 0.2879
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2373 - mae: 0.3049
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2586 - mae: 0.3014
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1929 - mae: 0.2748
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2641 - mae: 0.2951
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2291 - mae: 0.3048
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1963 - mae: 0.2299
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2287 - mae: 0.2650
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2978 - mae: 0.3568
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1927 - mae: 0.3063
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2697 - mae: 0.2928
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1792 - mae: 0.2778
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0959 - mae: 0.2129
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1530 - mae: 0.2473
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3329 - mae: 0.3230
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1663 - mae: 0.2488
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1713 - mae: 0.2570
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1785 - mae: 0.3029
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0936 - mae: 0.2240
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1987 - mae: 0.3106
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2038 - mae: 0.3059
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3441 - mae: 0.3469
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2485 - mae: 0.2838
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3011 - mae: 0.3159
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4353 - mae: 0.3371
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2277 - mae: 0.2833
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2880 - mae: 0.3228
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4fcdea4b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2746 - mae: 0.3377
# processing fold # 3
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 1.1902 - mae: 0.8656
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9801 - mae: 0.7934
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7494 - mae: 0.6138
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7776 - mae: 0.6378
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7295 - mae: 0.5591
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5111 - mae: 0.4787
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8429 - mae: 0.5578
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7624 - mae: 0.4798
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3796 - mae: 0.4484
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4989 - mae: 0.4816
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5993 - mae: 0.5168
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4149 - mae: 0.3909
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2865 - mae: 0.3400
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7448 - mae: 0.5109
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2907 - mae: 0.3322
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3664 - mae: 0.4221
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2905 - mae: 0.4102
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3079 - mae: 0.3735
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3958 - mae: 0.4171
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4290 - mae: 0.4664
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3653 - mae: 0.4034
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7252 - mae: 0.4917
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2624 - mae: 0.3326
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6587 - mae: 0.5062
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4119 - mae: 0.4279
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4937 - mae: 0.4402
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5342 - mae: 0.4584
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3873 - mae: 0.3794
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8436 - mae: 0.4950
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4965 - mae: 0.4484
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4900 - mae: 0.4467
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2890 - mae: 0.3516
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2559 - mae: 0.3624
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2333 - mae: 0.3480
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2701 - mae: 0.3507
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2757 - mae: 0.3511
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2252 - mae: 0.3426
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2028 - mae: 0.3237
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3161 - mae: 0.3553
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3132 - mae: 0.3986
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4649 - mae: 0.4071
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2415 - mae: 0.3611
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3594 - mae: 0.3610
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3653 - mae: 0.3863
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2536 - mae: 0.3629
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3264 - mae: 0.4104
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1563 - mae: 0.2649
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2294 - mae: 0.2871
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3394 - mae: 0.3888
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2996 - mae: 0.3542
# Epoch 51/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3506 - mae: 0.3751
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2875 - mae: 0.3053
# Epoch 53/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4680 - mae: 0.3964
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3232 - mae: 0.3671
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2019 - mae: 0.3092
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3900 - mae: 0.4331
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2730 - mae: 0.3493
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3246 - mae: 0.3831
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5651 - mae: 0.4354
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3591 - mae: 0.3527
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3692 - mae: 0.3722
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1887 - mae: 0.2869
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3575 - mae: 0.3295
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6697 - mae: 0.4361
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1189 - mae: 0.2508
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3061 - mae: 0.2861
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2875 - mae: 0.3040
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1863 - mae: 0.2952
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2448 - mae: 0.3227
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2530 - mae: 0.3186
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3215 - mae: 0.3618
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2256 - mae: 0.2873
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2728 - mae: 0.3760
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2286 - mae: 0.3179
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2801 - mae: 0.3131
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3154 - mae: 0.3671
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1266 - mae: 0.2578
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1394 - mae: 0.2526
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2945 - mae: 0.3104
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2747 - mae: 0.3396
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2360 - mae: 0.2892
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4767 - mae: 0.4122
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4230 - mae: 0.4030
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2625 - mae: 0.3169
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2663 - mae: 0.2710
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2366 - mae: 0.3293
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2536 - mae: 0.3387
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2080 - mae: 0.3003
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1911 - mae: 0.3004
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1098 - mae: 0.2393
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4218 - mae: 0.3922
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2880 - mae: 0.3156
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2151 - mae: 0.2780
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1762 - mae: 0.2846
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2327 - mae: 0.2841
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2221 - mae: 0.2469
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2492 - mae: 0.3071
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2320 - mae: 0.2753
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2253 - mae: 0.3247
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3100 - mae: 0.3554
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4fcdea40e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0992 - mae: 0.2210

# %% [markdown]
# # **Scores**
#
# Here we will see MAE mean absolute Error scores of all model which we have saved in the list during each training in above section

# %%
all_scores_relu
# Out:
# [0.30414727330207825,
#  0.31210780143737793,
#  0.3385695219039917,
#  0.2802779972553253]

# %%
all_scores_tanh
# Out:
# [0.30391794443130493,
#  0.3391397297382355,
#  0.4511507749557495,
#  0.299091100692749]

# %%
all_scores_regular
# Out:
# [0.304092675447464, 0.2492557018995285, 0.3299078345298767, 0.3934745192527771]

# %%
all_scores_drop
# Out:
# [0.40104904770851135,
#  0.43336978554725647,
#  0.3377233147621155,
#  0.2210151106119156]

# %% [markdown]
# # **Training on the training data**
#
# Here we will call each model separately from Models section and train on the training data and evaluate on the test data

# %%
model_tanh = build_model('tanh')
model_tanh.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_tanh.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4fca2499e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1130 - mae: 0.2534

# %%
model_relu = build_model('relu')
model_relu.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_relu.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4fc8306b00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0943 - mae: 0.2176

# %%
model_regular = build_model_regular('relu')
model_regular.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_regular.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4fcde80950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1487 - mae: 0.2434

# %%
model_drop = build_model_drop('relu')
model_drop.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_drop.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4fc719fd40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1667 - mae: 0.3304

# %% [markdown]
# # **Prediction Section**
#
# Here we will predict our prices of our test dataset with each model which we have trained in training section.
#
# Note that here we will use the reverse process of Normalization to retrieve our values of price in thousand of dollars i.e. x = (y - mean)/ std ==>> we will calculate( y = x * std + mean) and then we will compare it with our target values.

# %%
test_l
# Out:
# array([ 0.01414832,  0.3725343 ,  1.3658801 ,  2.122337  , -1.004718  ,
#        -0.7045773 , -0.5886972 , -0.97443527, -0.763189  , -0.52312535,
#        -0.05301089, -0.3704908 , -0.5449216 , -0.80397296, -0.5536523 ,
#        -0.26059392,  0.6062484 ,  1.4864004 ,  2.5404336 ,  3.367835  ,
#        -0.8779702 , -0.09159691,  0.18192424, -0.7802841 , -0.50065756,
#        -0.9622245 , -0.6813769 , -0.5409531 ,  0.01463675,  0.12453365,
#         0.46643507, -0.1806134 ,  0.2687428 ,  0.4299249 ,  0.45129374,
#        -0.07511237,  2.3382235 ,  2.200547  , -0.49870384,  0.20280465,
#         0.26019526, -0.68430746, -0.7224051 , -0.65524584, -0.98066276,
#        -0.7889537 , -0.7547636 , -0.6888255 , -0.6277716 , -0.4983375 ,
#        -0.6020069 , -0.4139611 , -0.22347318, -0.54107517,  0.28217462,
#        -0.68430746, -0.6574438 , -0.59638995, -0.01027321,  0.056886  ,
#        -0.1329914 , -0.05362143,  0.3181964 ,  0.6155285 ], dtype=float32)

# %%
def predict(model, m):
  print(f" the Actual value Price was : {test_l[m]* std_label + mean_label} " )
  return(f" the predicted Price was : {(model.predict(test[m:m+1].reshape(1,test.shape[1]))) * std_label + mean_label} ")

# %%
x_tanh = predict(model_tanh,2)
x_tanh
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[20869.182]] '

# %%
x_relu = predict(model_relu,2)
x_relu
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[19136.986]] '

# %%
x_regular = predict(model_regular,2)
x_regular
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[20649.35]] '

# %%
x_drop = predict(model_drop,2)
x_drop
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[22603.824]] '

# %%
def plot_fn(mod):
  y_true = test_l* std_label + mean_label
  y_pred = mod.predict(test) * std_label + mean_label
  return y_true , y_pred.flatten()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
def plotting(mod, label):
  y_true, y_pred = plot_fn(mod)
  coef = np.polyfit(y_true,y_pred,1)
  poly1d_fn = np.poly1d(coef) 
  # poly1d_fn is now a function which takes in x and returns an estimate for y
  plt.figure()
  plt.plot(y_true,y_pred, 'yo', y_true, poly1d_fn(y_true), '--k')
  plt.title(label)
  plt.xlabel('Thousand Dollar True' )
  plt.ylabel('Thousand Dollar Predictions' )
  plt.xlim(0, 50000)
  plt.ylim(0, 50000)

# %%
plot_list = []
for i,j in enumerate([model_relu, model_tanh, model_regular, model_drop]):
  list_name = ['model_relu', 'model_tanh', 'model_regular', 'model_drop']
  plot_list.append(plotting(j,list_name[i]))
